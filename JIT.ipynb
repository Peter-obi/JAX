# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-obi/JAX/blob/main/JIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SELU

# %%
import jax
import jax.numpy as jnp

# %%
def selu(x, alpha=1.6732632423543772848170429916717, scale=1.0507009873554804934193349852946):
  """Scaled exponential linear unit activation function"""
  return scale * jnp.where(x > 0, x, alpha * jnp.exp(x) - alpha) #jnp.where(condition, value_if_true, value_if_false)

# %%
x = jax.random.normal(jax.random.PRNGKey(42), (1_000_000,)) #generate a million random numbers
selu_jit = jax.jit(selu) #obtain a JIT-transformed version of the functionn
# %timeit -n100 selu(x).block_until_ready()
# Out:
# 1.3 ms ± 765 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n100 selu_jit(x).block_until_ready()
# Out:
# The slowest run took 5.28 times longer than the fastest. This could mean that an intermediate result is being cached.
# 222 µs ± 196 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
@jax.jit
def selu(x, alpha=1.6732632423543772848170429916717, scale=1.0507009873554804934193349852946):
  """Scaled exponential linear unit activation function"""
  return scale * jnp.where(x > 0, x, alpha * jnp.exp(x) - alpha)

# %%
z = selu(x) #warmup the function

# %%
# %timeit -n100 selu_jit(x).block_until_ready()
# Out:
# 147 µs ± 11.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#backend control
def selu(x, alpha=1.6732632423543772848170429916717, scale=1.0507009873554804934193349852946):
  """Scaled exponential linear unit activation function"""
  return scale * jnp.where(x > 0, x, alpha * jnp.exp(x) - alpha)

# %%
selu_jit_cpu = jax.jit(selu, backend = 'cpu')
selu_jit_gpu = jax.jit(selu, backend = 'gpu')

# %%
x = jax.random.normal(jax.random.PRNGKey(42), (1_000_000,))

# %%
# %timeit -n100 selu(x).block_until_ready() #uses gpu, just not JIT compiled
# Out:
# 1.3 ms ± 799 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n100 selu_jit_cpu(x).block_until_ready()
# Out:
# 2.36 ms ± 680 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n100 selu_jit_gpu(x).block_until_ready()
# Out:
# The slowest run took 5.09 times longer than the fastest. This could mean that an intermediate result is being cached.
# 227 µs ± 196 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ##Controlling both backend and tensor device placement

# %%
x_cpu = jax.device_put(x, jax.devices('cpu')[0])
x_gpu = jax.device_put(x, jax.devices('gpu')[0])

# %%
# %timeit -n100 selu(x_cpu).block_until_ready()
# Out:
# 7.53 ms ± 1.13 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n100 selu(x_gpu).block_until_ready()
# Out:
# 1.31 ms ± 754 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n100 selu_jit_cpu(x_cpu).block_until_ready()
# Out:
# 949 µs ± 65.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n100 selu_jit_gpu(x_gpu).block_until_ready()
# Out:
# 154 µs ± 8.91 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ##Static arguments

# %%
def dense_layer(x, w, b, activation_func): #function parameterized by another function
  return activation_func(x*w+b)

# %%
x = jnp.array([1.0, 2.0, 3.0])
w = jnp.ones((3, 3))
b = jnp.ones(3)

# %%
dense_layer_jit = jax.jit(dense_layer)

# %%
dense_layer_jit(x, w, b, selu)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1190478834.py in <cell line: 0>()
# ----> 1 dense_layer_jit(x, w, b, selu)
#
#     [... skipping hidden 5 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/pjit.py in _infer_input_type(fun, dbg, explicit_args)
#     678   except TypeError:
#     679     arg_description = f"path {dbg.arg_names[i] if dbg.arg_names is not None else 'unknown'}"  # pytype: disable=name-error
# --> 680     raise TypeError(
#     681       f"Error interpreting argument to {fun} as an abstract array."
#     682       f" The problematic value is of type {type(x)} and was passed to"  # pytype: disable=name-error
#
# TypeError: Error interpreting argument to <function dense_layer at 0x79c804315a80> as an abstract array. The problematic value is of type <class 'function'> and was passed to the function at path activation_func.
# This typically means that a jit-wrapped function was called with a non-array argument, and this argument was not marked as static using the static_argnums or static_argnames parameters of jax.jit.

# %%
dense_layer_jit = jax.jit(dense_layer, static_argnums=3)

# %%
dense_layer_jit(x, w, b, selu)
# Out:
# Array([[2.101402, 3.152103, 4.202804],
#        [2.101402, 3.152103, 4.202804],
#        [2.101402, 3.152103, 4.202804]], dtype=float32)

# %%
def dist(order, x, y):
  print('Compiling')
  return jnp.power(jnp.sum(jnp.abs(x-y)**order), 1.0/order)

# %%
dist_jit = jax.jit(dist, static_argnums=0)

# %%
dist_jit(1, jnp.array([0.0, 0.0]), jnp.array([2.0, 2.0])) #compile function for the given parameter value and run
# Out:
# Compiling
# Array(4., dtype=float32)

# %%
dist_jit(2, jnp.array([0.0, 0.0]), jnp.array([2.0, 2.0])) #compile function for another parameter value and run
# Out:
# Compiling
# Array(2.828427, dtype=float32)

# %%
dist_jit(1, jnp.array([10.0, 10.0]), jnp.array([2.0, 2.0])) #function already compiled
# Out:
# Array(16., dtype=float32)

# %% [markdown]
# #static arguments for jit decorator

# %%
from functools import partial

@partial(jax.jit, static_argnums = 0)
def dist(order, x, y):
  return jnp.power(jnp.sum(jnp.abs(x-y)**order), 1.0/order)

# %% [markdown]
# ##compiling an impure function

# %%
global_state = 1 #global state to be used in an impure function. impure functions depend on a global state and /or. have side effects.jax strips side effects after first call and it is not looged in Jaxpr

def impure_function(x):
  print(f'Side-efect: printing x={x}') #side effet of an impure function
  y = x*global_state
  return y

# %%
impure_function_jit = jax.jit(impure_function)

# %%
impure_function_jit(10)
# Out:
# Side-efect: printing x=JitTracer<~int32[]>
# Array(10, dtype=int32, weak_type=True)

# %%
impure_function_jit(10) #no side effects during second run
# Out:
# Array(10, dtype=int32, weak_type=True)

# %%
global_state = 2

# %%
impure_function_jit(10) #changed global state has no influence on the compiled function
# Out:
# Array(10, dtype=int32, weak_type=True)

# %%
impure_function(10)
# Out:
# Side-efect: printing x=10
# 20

# %% [markdown]
# ##JAXPR

# %%
def f1(x, y, z):
  return jnp.sum(x + y * z)

# %%
x = jnp.array([1.0, 1.0, 1.0])
y = jnp.ones((3,3))*2.0
z = jnp.array([2.0, 2.0, 0.0]).T

# %%
jax.make_jaxpr(f1) (x, y, z)  #generates jaxpr
# Out:
# { lambda ; a:f32[3] b:f32[3,3] c:f32[3]. let
#     d:f32[1,3] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 3)
#       sharding=None
#     ] c
#     e:f32[3,3] = mul b d
#     f:f32[1,3] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 3)
#       sharding=None
#     ] a
#     g:f32[3,3] = add f e
#     h:f32[] = reduce_sum[axes=(0, 1)] g
#   in (h,) }

# %%
def f2 (x,y):
  print(f'x={x}, y={y}, z={z}') #side effect
  return jnp.sum(x + y * z) #uses global variable z

# %%
f2_jaxpr = jax.make_jaxpr(f2) (x,y) #side effect z is present
# Out:
# x=JitTracer<float32[3]>, y=JitTracer<float32[3,3]>, z=[2. 2. 0.]

# %%
f2_jaxpr.jaxpr #doesn't capture side effect
# Out:
# { lambda a:f32[3]; b:f32[3] c:f32[3,3]. let
#     d:f32[1,3] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 3)
#       sharding=None
#     ] a
#     e:f32[3,3] = mul c d
#     f:f32[1,3] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 3)
#       sharding=None
#     ] b
#     g:f32[3,3] = add f e
#     h:f32[] = reduce_sum[axes=(0, 1)] g
#   in (h,) }

# %%
f2_jaxpr.consts #global varuable z is now a constant
# Out:
# [Array([2., 2., 0.], dtype=float32)]

# %% [markdown]
# ##Tracing

# %%
def f3(x):
  y = x
  for i in range(5): #loop does not depend on an input parameter - good.
    y += i
  return y

# %%
jax.make_jaxpr(f3)(0) #unroll loop
# Out:
# { lambda ; a:i32[]. let
#     b:i32[] = add a 0:i32[]
#     c:i32[] = add b 1:i32[]
#     d:i32[] = add c 2:i32[]
#     e:i32[] = add d 3:i32[]
#     f:i32[] = add e 4:i32[]
#   in (f,) }

# %%
jax.jit(f3) (0)
# Out:
# Array(10, dtype=int32, weak_type=True)

# %%
def f4(x):
  y = x
  for i in range(x.shape[0]): #loop depends on an input parameter shape- good.
    y += x[i]
  return y

# %%
jax.make_jaxpr(f4)(jnp.array([1.0, 2.0, 3.0])) #loop is unrolled
# Out:
# { lambda ; a:f32[3]. let
#     b:f32[1] = slice[limit_indices=(1,) start_indices=(0,) strides=None] a
#     c:f32[] = squeeze[dimensions=(0,)] b
#     d:f32[3] = add a c
#     e:f32[1] = slice[limit_indices=(2,) start_indices=(1,) strides=None] a
#     f:f32[] = squeeze[dimensions=(0,)] e
#     g:f32[3] = add d f
#     h:f32[1] = slice[limit_indices=(3,) start_indices=(2,) strides=None] a
#     i:f32[] = squeeze[dimensions=(0,)] h
#     j:f32[3] = add g i
#   in (j,) }

# %%
jax.jit(f4)(jnp.array([1.0, 2.0, 3.0]))
# Out:
# Array([7., 8., 9.], dtype=float32)

# %%
#depends on input parameter - crashes!
def f5(x):
  y = 0
  for i in range(x): #loop depend on input parameter
    y +=i
  return y

# %%
f5(5)
# Out:
# 10

# %%
jax.make_jaxpr(f5)(5)
# Out:
# ---------------------------------------------------------------------------
# TracerIntegerConversionError              Traceback (most recent call last)
# /tmp/ipython-input-1948442506.py in <cell line: 0>()
# ----> 1 jax.make_jaxpr(f5)(5)
#
#     [... skipping hidden 14 frame]
#
# /tmp/ipython-input-1812372770.py in f5(x)
#       2 def f5(x):
#       3   y = 0
# ----> 4   for i in range(x):
#       5     y +=i
#       6   return y
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/core.py in error(self, arg)
#    1807   elif fun in (hex, oct, operator.index):
#    1808     def error(self, arg):
# -> 1809       raise TracerIntegerConversionError(arg)
#    1810   else:
#    1811     def error(self, arg):
#
# TracerIntegerConversionError: The __index__() method was called on traced array with shape int32[]
# The error occurred while tracing the function f5 at /tmp/ipython-input-1812372770.py:2 for jit. This concrete value was not available in Python because it depends on the value of the argument x.
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.TracerIntegerConversionError

# %%
#same here
def relu(x):
  if x > 0:   #if statement depends on input parameter
    return x
  return 0.0

# %%
relu(10.0)
# Out:
# 10.0

# %%
jax.make_jaxpr(relu)(10.0)
# Out:
# ---------------------------------------------------------------------------
# TracerBoolConversionError                 Traceback (most recent call last)
# /tmp/ipython-input-1243825792.py in <cell line: 0>()
# ----> 1 jax.make_jaxpr(relu)(10.0)
#
#     [... skipping hidden 14 frame]
#
# /tmp/ipython-input-739987649.py in relu(x)
#       1 #same here
#       2 def relu(x):
# ----> 3   if x > 0:
#       4     return x
#       5   return 0.0
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/core.py in error(self, arg)
#    1804   if fun is bool:
#    1805     def error(self, arg):
# -> 1806       raise TracerBoolConversionError(arg)
#    1807   elif fun in (hex, oct, operator.index):
#    1808     def error(self, arg):
#
# TracerBoolConversionError: Attempted boolean conversion of traced array with shape bool[].
# The error occurred while tracing the function relu at /tmp/ipython-input-739987649.py:2 for jit. This concrete value was not available in Python because it depends on the value of the argument x.
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.TracerBoolConversionError

# %%
jax.make_jaxpr(f5, static_argnums=0) (5) #same argument but we use static_argnums to mark first parameter as static as in JIT to escape
# Out:
# { lambda ; . let  in (10:i32[],) }

# %%
jax.jit(f5, static_argnums=0)(5)
# Out:
# Array(10, dtype=int32, weak_type=True)

# %%
jax.make_jaxpr(relu, static_argnums=0)(10.0)
# Out:
# { lambda ; . let  in (10.0:f32[],) }

# %%
jax.jit(relu, static_argnums=0)(10.0)
# Out:
# Array(10., dtype=float32, weak_type=True)

# %%
#another way to solve, use fori loop -> lax primitive
def fori_loop(lower, upper, body_fun, init_val):
  val = init_val
  for i in range(lower, upper):
    val = body_fun(i, val)
  return val

# %%
def f5(x):
  return jax.lax.fori_loop(0, x, lambda i, v: v+i, 0) #replace the for loop

# %%
f5(5)
# Out:
# Array(10, dtype=int32, weak_type=True)

# %%
jax.make_jaxpr(f5)(5)
# Out:
# { lambda ; a:i32[]. let
#     _:i32[] _:i32[] b:i32[] = while[
#       body_jaxpr={ lambda ; c:i32[] d:i32[] e:i32[]. let
#           f:i32[] = add c 1:i32[]
#           g:i32[] = add e c
#         in (f, d, g) }
#       body_nconsts=0
#       cond_jaxpr={ lambda ; h:i32[] i:i32[] j:i32[]. let
#           k:bool[] = lt h i
#         in (k,) }
#       cond_nconsts=0
#     ] 0:i32[] a 0:i32[]
#   in (b,) }

# %%
jax.jit(f5)(5)
# Out:
# Array(10, dtype=int32, weak_type=True)

# %% [markdown]
# HLO

# %%
def f(x, y, z):
  return jnp.sum(x + y * z)

# %%
x = jnp.array([1.0, 1.0, 1.0])
y = jnp.ones((3,3))*2.0
z = jnp.array([2.0, 2.0, 0.0]).T

# %%
f_jitted = jax.jit(f)

# %%
f_lowered= f_jitted.lower(x, y, z) #lowers the function, geenerating StableHLO

# %%
print(f_lowered.as_text())
# Out:
# module @jit_f attributes {mhlo.num_partitions = 1 : i32, mhlo.num_replicas = 1 : i32} {
#   func.func public @main(%arg0: tensor<3xf32>, %arg1: tensor<3x3xf32>, %arg2: tensor<3xf32>) -> (tensor<f32> {jax.result_info = "result"}) {
#     %0 = stablehlo.broadcast_in_dim %arg2, dims = [1] : (tensor<3xf32>) -> tensor<1x3xf32>
#     %1 = stablehlo.broadcast_in_dim %0, dims = [0, 1] : (tensor<1x3xf32>) -> tensor<3x3xf32>
#     %2 = stablehlo.multiply %arg1, %1 : tensor<3x3xf32>
#     %3 = stablehlo.broadcast_in_dim %arg0, dims = [1] : (tensor<3xf32>) -> tensor<1x3xf32>
#     %4 = stablehlo.broadcast_in_dim %3, dims = [0, 1] : (tensor<1x3xf32>) -> tensor<3x3xf32>
#     %5 = stablehlo.add %4, %2 : tensor<3x3xf32>
#     %cst = stablehlo.constant dense<0.000000e+00> : tensor<f32>
#     %6 = stablehlo.reduce(%5 init: %cst) applies stablehlo.add across dimensions = [0, 1] : (tensor<3x3xf32>, tensor<f32>) -> tensor<f32>
#     return %6 : tensor<f32>
#   }
# }

# %%
f_compiled = f_jitted.lower(x, y, z).compile() #compiles the lowered function for the specific backend (generating HLO code)
print(f_compiled.as_text())
# Out:
# HloModule jit_f, is_scheduled=true, entry_computation_layout={(f32[3]{0}, f32[3,3]{1,0}, f32[3]{0})->f32[]}, allow_spmd_sharding_propagation_to_parameters={true,true,true}, allow_spmd_sharding_propagation_to_output={true}
#
# %region_0.1 (reduce_sum.3: f32[], reduce_sum.4: f32[]) -> f32[] {
#   %reduce_sum.3 = f32[] parameter(0), metadata={op_name="reduce_sum"}
#   %reduce_sum.4 = f32[] parameter(1), metadata={op_name="reduce_sum"}
#   ROOT %reduce_sum.5 = f32[] add(%reduce_sum.3, %reduce_sum.4), metadata={op_name="jit(f)/reduce_sum" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=9 source_end_column=26}
# }
#
# %fused_computation (param_0.3: f32[3,3], param_1.4: f32[3], param_2.3: f32[3]) -> f32[] {
#   %param_2.3 = f32[3]{0} parameter(2)
#   %add.1 = f32[3,3]{1,0} broadcast(%param_2.3), dimensions={1}, metadata={op_name="jit(f)/add" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=17 source_end_column=25}
#   %param_0.3 = f32[3,3]{1,0} parameter(0)
#   %param_1.4 = f32[3]{0} parameter(1)
#   %mul.1 = f32[3,3]{1,0} broadcast(%param_1.4), dimensions={1}, metadata={op_name="jit(f)/mul" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=21 source_end_column=25}
#   %mul.0 = f32[3,3]{1,0} multiply(%param_0.3, %mul.1), metadata={op_name="jit(f)/mul" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=21 source_end_column=25}
#   %add.0 = f32[3,3]{1,0} add(%add.1, %mul.0), metadata={op_name="jit(f)/add" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=17 source_end_column=25}
#   %constant.0 = f32[] constant(0)
#   ROOT %reduce_sum.0 = f32[] reduce(%add.0, %constant.0), dimensions={0,1}, to_apply=%region_0.1, metadata={op_name="jit(f)/reduce_sum" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=9 source_end_column=26}
# }
#
# ENTRY %main.2 (x.1: f32[3], y.1: f32[3,3], z.1: f32[3]) -> f32[] {
#   %x.1 = f32[3]{0} parameter(0), metadata={op_name="x"}
#   %y.1 = f32[3,3]{1,0} parameter(1), metadata={op_name="y"}
#   %z.1 = f32[3]{0} parameter(2), metadata={op_name="z"}
#   ROOT %add_reduce_fusion = f32[] fusion(%y.1, %z.1, %x.1), kind=kLoop, calls=%fused_computation, metadata={op_name="jit(f)/reduce_sum" source_file="/tmp/ipython-input-1761176124.py" source_line=2 source_end_line=2 source_column=9 source_end_column=26}
# }

# %% [markdown]
# ##Compile with JIT and AOT

# %%
def selu(x, alpha=1.6732632423543772848170429916717, scale=1.0507009873554804934193349852946):
  """Scaled exponential linear unit activation function"""
  print("Function run") #side effect
  return scale * jnp.where(x > 0, x, alpha * jnp.exp(x) - alpha)

# %%
selu_jit = jax.jit(selu)

# %%
selu_aot = jax.jit(selu).lower(1.0).compile() #AOT-compiled function,fictional 1.0 argument; needed for AOT to infer types
# Out:
# Function run

# %%
selu_jit(17.8)
# Out:
# Function run
# Array(18.702477, dtype=float32, weak_type=True)

# %%
selu_aot(17.8)
# Out:
# Array(18.702477, dtype=float32, weak_type=True)

# %%
selu_jit(17) #JIT function has to be recompiled
# Out:
# Function run
# Array(17.861917, dtype=float32, weak_type=True)

# %%
selu_aot(17) #throws a type error for. using an interger when we compiled with a float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3083113866.py in <cell line: 0>()
# ----> 1 selu_aot(17)
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/stages.py in __call__(self, *args, **kwargs)
#     810           return outs
#     811         self._call = cpp_call_fallback
# --> 812     return self._call(*args, **kwargs)
#     813
#     814
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/interpreters/pxla.py in aot_cache_miss(*args, **kwargs)
#    3285       # args do not include the const args.
#    3286       # See https://docs.jax.dev/en/latest/internals/constants.html.
# -> 3287       outs, out_flat, args_flat = stages.Compiled.call(params, *args, **kwargs)
#    3288       out_flat, out_tree_dispatch = reflatten_outputs_for_dispatch(
#    3289           params.out_tree, out_flat)
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/stages.py in call(*args, **kwargs)
#     797               "compiled for a particular signature. Detected argument of "
#     798               f"Tracer type {type(arg)}.")
# --> 799     out_flat = params.executable.call(*params.const_args, *args_flat)
#     800     outs = tree_util.tree_unflatten(params.out_tree, out_flat)
#     801     return outs, out_flat, args_flat
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/interpreters/pxla.py in call(self, *args)
#    3255     if self._all_args_info is not None:
#    3256       # We check all args before DCE
# -> 3257       check_arg_avals_for_call(self._all_args_info.in_avals,
#    3258                                map(core.shaped_abstractify, args),
#    3259                                self._all_args_info.debug_info)
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/interpreters/pxla.py in check_arg_avals_for_call(ref_avals, arg_avals, jaxpr_debug_info)
#    3346     else:
#    3347       num_mismatch_str = "The"
# -> 3348     raise TypeError(
#    3349         "Argument types differ from the types for which this computation was "
#    3350         "compiled. Perhaps you are calling the compiled executable with a "
#
# TypeError: Argument types differ from the types for which this computation was compiled. Perhaps you are calling the compiled executable with a different enable_x64 mode than when it was AOT compiled? The mismatches are:
# Argument 'x' compiled with float32[] and called with int32[]

# %%
selu_jit_batched = jax.vmap(selu_jit) #create batched versions of the function
selu_aot_batched = jax.vmap(selu_aot)

# %%
selu_jit_batched(jnp.array([42.0, 78.0, -12.3]))
# Out:
# Function run
# Array([44.129444 , 81.95468  , -1.7580913], dtype=float32)

# %%
selu_aot_batched(jnp.array([42.0, 78.0, -12.3])) #can't be transformed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-703517280.py in <cell line: 0>()
# ----> 1 selu_aot_batched(jnp.array([42.0, 78.0, -12.3]))
#
#     [... skipping hidden 9 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/stages.py in call(*args, **kwargs)
#     793       for arg in args_flat:
#     794         if isinstance(arg, core.Tracer):
# --> 795           raise TypeError(
#     796               "Cannot apply JAX transformations to a function lowered and "
#     797               "compiled for a particular signature. Detected argument of "
#
# TypeError: Cannot apply JAX transformations to a function lowered and compiled for a particular signature. Detected argument of Tracer type <class 'jax._src.interpreters.batching.BatchTracer'>.

# %% [markdown]
# ##Comparing compilation times

# %%
def cumulative_sum(x):
  acc = 0.0
  y = []
  for i in range(x.shape[0]):
    acc +=x[i]
    y.append(acc)
  return y

# %%
j = jax.make_jaxpr(cumulative_sum)(jnp.ones(10000))

# %%
len(j.jaxpr.eqns) #jaxpr has 30000 lines
# Out:
# 30000

# %%
# %time jax.jit(cumulative_sum)(jnp.ones(10000))
# Out:
# CPU times: user 47.8 ms, sys: 972 µs, total: 48.8 ms
# Wall time: 38.7 ms
# [Array(1., dtype=float32),
#  Array(2., dtype=float32),
#  Array(3., dtype=float32),
#  Array(4., dtype=float32),
#  Array(5., dtype=float32),
#  Array(6., dtype=float32),
#  Array(7., dtype=float32),
#  Array(8., dtype=float32),
#  Array(9., dtype=float32),
#  Array(10., dtype=float32),
#  Array(11., dtype=float32),
#  Array(12., dtype=float32),
#  Array(13., dtype=float32),
#  Array(14., dtype=float32),
#  Array(15., dtype=float32),
#  Array(16., dtype=float32),
#  Array(17., dtype=float32),
#  Array(18., dtype=float32),
#  Array(19., dtype=float32),
#  Array(20., dtype=float32),
#  Array(21., dtype=float32),
#  Array(22., dtype=float32),
#  Array(23., dtype=float32),
#  Array(24., dtype=float32),
#  Array(25., dtype=float32),
#  Array(26., dtype=float32),
#  Array(27., dtype=float32),
#  Array(28., dtype=float32),
#  Array(29., dtype=float32),
#  Array(30., dtype=float32),
#  Array(31., dtype=float32),
#  Array(32., dtype=float32),
#  Array(33., dtype=float32),
#  Array(34., dtype=float32),
#  Array(35., dtype=float32),
#  Array(36., dtype=float32),
#  Array(37., dtype=float32),
#  Array(38., dtype=float32),
#  Array(39., dtype=float32),
#  Array(40., dtype=float32),
#  Array(41., dtype=float32),
#  Array(42., dtype=float32),
#  Array(43., dtype=float32),
#  Array(44., dtype=float32),
#  Array(45., dtype=float32),
#  Array(46., dtype=float32),
#  Array(47., dtype=float32),
#  Array(48., dtype=float32),
#  Array(49., dtype=float32),
#  Array(50., dtype=float32),
#  Array(51., dtype=float32),
#  Array(52., dtype=float32),
#  Array(53., dtype=float32),
#  Array(54., dtype=float32),
#  Array(55., dtype=float32),
#  Array(56., dtype=float32),
#  Array(57., dtype=float32),
#  Array(58., dtype=float32),
#  Array(59., dtype=float32),
#  Array(60., dtype=float32),
#  Array(61., dtype=float32),
#  Array(62., dtype=float32),
#  Array(63., dtype=float32),
#  Array(64., dtype=float32),
#  Array(65., dtype=float32),
#  Array(66., dtype=float32),
#  Array(67., dtype=float32),
#  Array(68., dtype=float32),
#  Array(69., dtype=float32),
#  Array(70., dtype=float32),
#  Array(71., dtype=float32),
#  Array(72., dtype=float32),
#  Array(73., dtype=float32),
#  Array(74., dtype=float32),
#  Array(75., dtype=float32),
#  Array(76., dtype=float32),
#  Array(77., dtype=float32),
#  Array(78., dtype=float32),
#  Array(79., dtype=float32),
#  Array(80., dtype=float32),
#  Array(81., dtype=float32),
#  Array(82., dtype=float32),
#  Array(83., dtype=float32),
#  Array(84., dtype=float32),
#  Array(85., dtype=float32),
#  Array(86., dtype=float32),
#  Array(87., dtype=float32),
#  Array(88., dtype=float32),
#  Array(89., dtype=float32),
#  Array(90., dtype=float32),
#  Array(91., dtype=float32),
#  Array(92., dtype=float32),
#  Array(93., dtype=float32),
#  Array(94., dtype=float32),
#  Array(95., dtype=float32),
#  Array(96., dtype=float32),
#  Array(97., dtype=float32),
#  Array(98., dtype=float32),
#  Array(99., dtype=float32),
#  Array(100., dtype=float32),
#  Array(101., dtype=float32),
#  Array(102., dtype=float32),
#  Array(103., dtype=float32),
#  Array(104., dtype=float32),
#  Array(105., dtype=float32),
#  Array(106., dtype=float32),
#  Array(107., dtype=float32),
#  Array(108., dtype=float32),
#  Array(109., dtype=float32),
#  Array(110., dtype=float32),
#  Array(111., dtype=float32),
#  Array(112., dtype=float32),
#  Array(113., dtype=float32),
#  Array(114., dtype=float32),
#  Array(115., dtype=float32),
#  Array(116., dtype=float32),
#  Array(117., dtype=float32),
#  Array(118., dtype=float32),
#  Array(119., dtype=float32),
#  Array(120., dtype=float32),
#  Array(121., dtype=float32),
#  Array(122., dtype=float32),
#  Array(123., dtype=float32),
#  Array(124., dtype=float32),
#  Array(125., dtype=float32),
#  Array(126., dtype=float32),
#  Array(127., dtype=float32),
#  Array(128., dtype=float32),
#  Array(129., dtype=float32),
#  Array(130., dtype=float32),
#  Array(131., dtype=float32),
#  Array(132., dtype=float32),
#  Array(133., dtype=float32),
#  Array(134., dtype=float32),
#  Array(135., dtype=float32),
#  Array(136., dtype=float32),
#  Array(137., dtype=float32),
#  Array(138., dtype=float32),
#  Array(139., dtype=float32),
#  Array(140., dtype=float32),
#  Array(141., dtype=float32),
#  Array(142., dtype=float32),
#  Array(143., dtype=float32),
#  Array(144., dtype=float32),
#  Array(145., dtype=float32),
#  Array(146., dtype=float32),
#  Array(147., dtype=float32),
#  Array(148., dtype=float32),
#  Array(149., dtype=float32),
#  Array(150., dtype=float32),
#  Array(151., dtype=float32),
#  Array(152., dtype=float32),
#  Array(153., dtype=float32),
#  Array(154., dtype=float32),
#  Array(155., dtype=float32),
#  Array(156., dtype=float32),
#  Array(157., dtype=float32),
#  Array(158., dtype=float32),
#  Array(159., dtype=float32),
#  Array(160., dtype=float32),
#  Array(161., dtype=float32),
#  Array(162., dtype=float32),
#  Array(163., dtype=float32),
#  Array(164., dtype=float32),
#  Array(165., dtype=float32),
#  Array(166., dtype=float32),
#  Array(167., dtype=float32),
#  Array(168., dtype=float32),
#  Array(169., dtype=float32),
#  Array(170., dtype=float32),
#  Array(171., dtype=float32),
#  Array(172., dtype=float32),
#  Array(173., dtype=float32),
#  Array(174., dtype=float32),
#  Array(175., dtype=float32),
#  Array(176., dtype=float32),
#  Array(177., dtype=float32),
#  Array(178., dtype=float32),
#  Array(179., dtype=float32),
#  Array(180., dtype=float32),
#  Array(181., dtype=float32),
#  Array(182., dtype=float32),
#  Array(183., dtype=float32),
#  Array(184., dtype=float32),
#  Array(185., dtype=float32),
#  Array(186., dtype=float32),
#  Array(187., dtype=float32),
#  Array(188., dtype=float32),
#  Array(189., dtype=float32),
#  Array(190., dtype=float32),
#  Array(191., dtype=float32),
#  Array(192., dtype=float32),
#  Array(193., dtype=float32),
#  Array(194., dtype=float32),
#  Array(195., dtype=float32),
#  Array(196., dtype=float32),
#  Array(197., dtype=float32),
#  Array(198., dtype=float32),
#  Array(199., dtype=float32),
#  Array(200., dtype=float32),
#  Array(201., dtype=float32),
#  Array(202., dtype=float32),
#  Array(203., dtype=float32),
#  Array(204., dtype=float32),
#  Array(205., dtype=float32),
#  Array(206., dtype=float32),
#  Array(207., dtype=float32),
#  Array(208., dtype=float32),
#  Array(209., dtype=float32),
#  Array(210., dtype=float32),
#  Array(211., dtype=float32),
#  Array(212., dtype=float32),
#  Array(213., dtype=float32),
#  Array(214., dtype=float32),
#  Array(215., dtype=float32),
#  Array(216., dtype=float32),
#  Array(217., dtype=float32),
#  Array(218., dtype=float32),
#  Array(219., dtype=float32),
#  Array(220., dtype=float32),
#  Array(221., dtype=float32),
#  Array(222., dtype=float32),
#  Array(223., dtype=float32),
#  Array(224., dtype=float32),
#  Array(225., dtype=float32),
#  Array(226., dtype=float32),
#  Array(227., dtype=float32),
#  Array(228., dtype=float32),
#  Array(229., dtype=float32),
#  Array(230., dtype=float32),
#  Array(231., dtype=float32),
#  Array(232., dtype=float32),
#  Array(233., dtype=float32),
#  Array(234., dtype=float32),
#  Array(235., dtype=float32),
#  Array(236., dtype=float32),
#  Array(237., dtype=float32),
#  Array(238., dtype=float32),
#  Array(239., dtype=float32),
#  Array(240., dtype=float32),
#  Array(241., dtype=float32),
#  Array(242., dtype=float32),
#  Array(243., dtype=float32),
#  Array(244., dtype=float32),
#  Array(245., dtype=float32),
#  Array(246., dtype=float32),
#  Array(247., dtype=float32),
#  Array(248., dtype=float32),
#  Array(249., dtype=float32),
#  Array(250., dtype=float32),
#  Array(251., dtype=float32),
#  Array(252., dtype=float32),
#  Array(253., dtype=float32),
#  Array(254., dtype=float32),
#  Array(255., dtype=float32),
#  Array(256., dtype=float32),
#  Array(257., dtype=float32),
#  Array(258., dtype=float32),
#  Array(259., dtype=float32),
#  Array(260., dtype=float32),
#  Array(261., dtype=float32),
#  Array(262., dtype=float32),
#  Array(263., dtype=float32),
#  Array(264., dtype=float32),
#  Array(265., dtype=float32),
#  Array(266., dtype=float32),
#  Array(267., dtype=float32),
#  Array(268., dtype=float32),
#  Array(269., dtype=float32),
#  Array(270., dtype=float32),
#  Array(271., dtype=float32),
#  Array(272., dtype=float32),
#  Array(273., dtype=float32),
#  Array(274., dtype=float32),
#  Array(275., dtype=float32),
#  Array(276., dtype=float32),
#  Array(277., dtype=float32),
#  Array(278., dtype=float32),
#  Array(279., dtype=float32),
#  Array(280., dtype=float32),
#  Array(281., dtype=float32),
#  Array(282., dtype=float32),
#  Array(283., dtype=float32),
#  Array(284., dtype=float32),
#  Array(285., dtype=float32),
#  Array(286., dtype=float32),
#  Array(287., dtype=float32),
#  Array(288., dtype=float32),
#  Array(289., dtype=float32),
#  Array(290., dtype=float32),
#  Array(291., dtype=float32),
#  Array(292., dtype=float32),
#  Array(293., dtype=float32),
#  Array(294., dtype=float32),
#  Array(295., dtype=float32),
#  Array(296., dtype=float32),
#  Array(297., dtype=float32),
#  Array(298., dtype=float32),
#  Array(299., dtype=float32),
#  Array(300., dtype=float32),
#  Array(301., dtype=float32),
#  Array(302., dtype=float32),
#  Array(303., dtype=float32),
#  Array(304., dtype=float32),
#  Array(305., dtype=float32),
#  Array(306., dtype=float32),
#  Array(307., dtype=float32),
#  Array(308., dtype=float32),
#  Array(309., dtype=float32),
#  Array(310., dtype=float32),
#  Array(311., dtype=float32),
#  Array(312., dtype=float32),
#  Array(313., dtype=float32),
#  Array(314., dtype=float32),
#  Array(315., dtype=float32),
#  Array(316., dtype=float32),
#  Array(317., dtype=float32),
#  Array(318., dtype=float32),
#  Array(319., dtype=float32),
#  Array(320., dtype=float32),
#  Array(321., dtype=float32),
#  Array(322., dtype=float32),
#  Array(323., dtype=float32),
#  Array(324., dtype=float32),
#  Array(325., dtype=float32),
#  Array(326., dtype=float32),
#  Array(327., dtype=float32),
#  Array(328., dtype=float32),
#  Array(329., dtype=float32),
#  Array(330., dtype=float32),
#  Array(331., dtype=float32),
#  Array(332., dtype=float32),
#  Array(333., dtype=float32),
#  Array(334., dtype=float32),
#  Array(335., dtype=float32),
#  Array(336., dtype=float32),
#  Array(337., dtype=float32),
#  Array(338., dtype=float32),
#  Array(339., dtype=float32),
#  Array(340., dtype=float32),
#  Array(341., dtype=float32),
#  Array(342., dtype=float32),
#  Array(343., dtype=float32),
#  Array(344., dtype=float32),
#  Array(345., dtype=float32),
#  Array(346., dtype=float32),
#  Array(347., dtype=float32),
#  Array(348., dtype=float32),
#  Array(349., dtype=float32),
#  Array(350., dtype=float32),
#  Array(351., dtype=float32),
#  Array(352., dtype=float32),
#  Array(353., dtype=float32),
#  Array(354., dtype=float32),
#  Array(355., dtype=float32),
#  Array(356., dtype=float32),
#  Array(357., dtype=float32),
#  Array(358., dtype=float32),
#  Array(359., dtype=float32),
#  Array(360., dtype=float32),
#  Array(361., dtype=float32),
#  Array(362., dtype=float32),
#  Array(363., dtype=float32),
#  Array(364., dtype=float32),
#  Array(365., dtype=float32),
#  Array(366., dtype=float32),
#  Array(367., dtype=float32),
#  Array(368., dtype=float32),
#  Array(369., dtype=float32),
#  Array(370., dtype=float32),
#  Array(371., dtype=float32),
#  Array(372., dtype=float32),
#  Array(373., dtype=float32),
#  Array(374., dtype=float32),
#  Array(375., dtype=float32),
#  Array(376., dtype=float32),
#  Array(377., dtype=float32),
#  Array(378., dtype=float32),
#  Array(379., dtype=float32),
#  Array(380., dtype=float32),
#  Array(381., dtype=float32),
#  Array(382., dtype=float32),
#  Array(383., dtype=float32),
#  Array(384., dtype=float32),
#  Array(385., dtype=float32),
#  Array(386., dtype=float32),
#  Array(387., dtype=float32),
#  Array(388., dtype=float32),
#  Array(389., dtype=float32),
#  Array(390., dtype=float32),
#  Array(391., dtype=float32),
#  Array(392., dtype=float32),
#  Array(393., dtype=float32),
#  Array(394., dtype=float32),
#  Array(395., dtype=float32),
#  Array(396., dtype=float32),
#  Array(397., dtype=float32),
#  Array(398., dtype=float32),
#  Array(399., dtype=float32),
#  Array(400., dtype=float32),
#  Array(401., dtype=float32),
#  Array(402., dtype=float32),
#  Array(403., dtype=float32),
#  Array(404., dtype=float32),
#  Array(405., dtype=float32),
#  Array(406., dtype=float32),
#  Array(407., dtype=float32),
#  Array(408., dtype=float32),
#  Array(409., dtype=float32),
#  Array(410., dtype=float32),
#  Array(411., dtype=float32),
#  Array(412., dtype=float32),
#  Array(413., dtype=float32),
#  Array(414., dtype=float32),
#  Array(415., dtype=float32),
#  Array(416., dtype=float32),
#  Array(417., dtype=float32),
#  Array(418., dtype=float32),
#  Array(419., dtype=float32),
#  Array(420., dtype=float32),
#  Array(421., dtype=float32),
#  Array(422., dtype=float32),
#  Array(423., dtype=float32),
#  Array(424., dtype=float32),
#  Array(425., dtype=float32),
#  Array(426., dtype=float32),
#  Array(427., dtype=float32),
#  Array(428., dtype=float32),
#  Array(429., dtype=float32),
#  Array(430., dtype=float32),
#  Array(431., dtype=float32),
#  Array(432., dtype=float32),
#  Array(433., dtype=float32),
#  Array(434., dtype=float32),
#  Array(435., dtype=float32),
#  Array(436., dtype=float32),
#  Array(437., dtype=float32),
#  Array(438., dtype=float32),
#  Array(439., dtype=float32),
#  Array(440., dtype=float32),
#  Array(441., dtype=float32),
#  Array(442., dtype=float32),
#  Array(443., dtype=float32),
#  Array(444., dtype=float32),
#  Array(445., dtype=float32),
#  Array(446., dtype=float32),
#  Array(447., dtype=float32),
#  Array(448., dtype=float32),
#  Array(449., dtype=float32),
#  Array(450., dtype=float32),
#  Array(451., dtype=float32),
#  Array(452., dtype=float32),
#  Array(453., dtype=float32),
#  Array(454., dtype=float32),
#  Array(455., dtype=float32),
#  Array(456., dtype=float32),
#  Array(457., dtype=float32),
#  Array(458., dtype=float32),
#  Array(459., dtype=float32),
#  Array(460., dtype=float32),
#  Array(461., dtype=float32),
#  Array(462., dtype=float32),
#  Array(463., dtype=float32),
#  Array(464., dtype=float32),
#  Array(465., dtype=float32),
#  Array(466., dtype=float32),
#  Array(467., dtype=float32),
#  Array(468., dtype=float32),
#  Array(469., dtype=float32),
#  Array(470., dtype=float32),
#  Array(471., dtype=float32),
#  Array(472., dtype=float32),
#  Array(473., dtype=float32),
#  Array(474., dtype=float32),
#  Array(475., dtype=float32),
#  Array(476., dtype=float32),
#  Array(477., dtype=float32),
#  Array(478., dtype=float32),
#  Array(479., dtype=float32),
#  Array(480., dtype=float32),
#  Array(481., dtype=float32),
#  Array(482., dtype=float32),
#  Array(483., dtype=float32),
#  Array(484., dtype=float32),
#  Array(485., dtype=float32),
#  Array(486., dtype=float32),
#  Array(487., dtype=float32),
#  Array(488., dtype=float32),
#  Array(489., dtype=float32),
#  Array(490., dtype=float32),
#  Array(491., dtype=float32),
#  Array(492., dtype=float32),
#  Array(493., dtype=float32),
#  Array(494., dtype=float32),
#  Array(495., dtype=float32),
#  Array(496., dtype=float32),
#  Array(497., dtype=float32),
#  Array(498., dtype=float32),
#  Array(499., dtype=float32),
#  Array(500., dtype=float32),
#  Array(501., dtype=float32),
#  Array(502., dtype=float32),
#  Array(503., dtype=float32),
#  Array(504., dtype=float32),
#  Array(505., dtype=float32),
#  Array(506., dtype=float32),
#  Array(507., dtype=float32),
#  Array(508., dtype=float32),
#  Array(509., dtype=float32),
#  Array(510., dtype=float32),
#  Array(511., dtype=float32),
#  Array(512., dtype=float32),
#  Array(513., dtype=float32),
#  Array(514., dtype=float32),
#  Array(515., dtype=float32),
#  Array(516., dtype=float32),
#  Array(517., dtype=float32),
#  Array(518., dtype=float32),
#  Array(519., dtype=float32),
#  Array(520., dtype=float32),
#  Array(521., dtype=float32),
#  Array(522., dtype=float32),
#  Array(523., dtype=float32),
#  Array(524., dtype=float32),
#  Array(525., dtype=float32),
#  Array(526., dtype=float32),
#  Array(527., dtype=float32),
#  Array(528., dtype=float32),
#  Array(529., dtype=float32),
#  Array(530., dtype=float32),
#  Array(531., dtype=float32),
#  Array(532., dtype=float32),
#  Array(533., dtype=float32),
#  Array(534., dtype=float32),
#  Array(535., dtype=float32),
#  Array(536., dtype=float32),
#  Array(537., dtype=float32),
#  Array(538., dtype=float32),
#  Array(539., dtype=float32),
#  Array(540., dtype=float32),
#  Array(541., dtype=float32),
#  Array(542., dtype=float32),
#  Array(543., dtype=float32),
#  Array(544., dtype=float32),
#  Array(545., dtype=float32),
#  Array(546., dtype=float32),
#  Array(547., dtype=float32),
#  Array(548., dtype=float32),
#  Array(549., dtype=float32),
#  Array(550., dtype=float32),
#  Array(551., dtype=float32),
#  Array(552., dtype=float32),
#  Array(553., dtype=float32),
#  Array(554., dtype=float32),
#  Array(555., dtype=float32),
#  Array(556., dtype=float32),
#  Array(557., dtype=float32),
#  Array(558., dtype=float32),
#  Array(559., dtype=float32),
#  Array(560., dtype=float32),
#  Array(561., dtype=float32),
#  Array(562., dtype=float32),
#  Array(563., dtype=float32),
#  Array(564., dtype=float32),
#  Array(565., dtype=float32),
#  Array(566., dtype=float32),
#  Array(567., dtype=float32),
#  Array(568., dtype=float32),
#  Array(569., dtype=float32),
#  Array(570., dtype=float32),
#  Array(571., dtype=float32),
#  Array(572., dtype=float32),
#  Array(573., dtype=float32),
#  Array(574., dtype=float32),
#  Array(575., dtype=float32),
#  Array(576., dtype=float32),
#  Array(577., dtype=float32),
#  Array(578., dtype=float32),
#  Array(579., dtype=float32),
#  Array(580., dtype=float32),
#  Array(581., dtype=float32),
#  Array(582., dtype=float32),
#  Array(583., dtype=float32),
#  Array(584., dtype=float32),
#  Array(585., dtype=float32),
#  Array(586., dtype=float32),
#  Array(587., dtype=float32),
#  Array(588., dtype=float32),
#  Array(589., dtype=float32),
#  Array(590., dtype=float32),
#  Array(591., dtype=float32),
#  Array(592., dtype=float32),
#  Array(593., dtype=float32),
#  Array(594., dtype=float32),
#  Array(595., dtype=float32),
#  Array(596., dtype=float32),
#  Array(597., dtype=float32),
#  Array(598., dtype=float32),
#  Array(599., dtype=float32),
#  Array(600., dtype=float32),
#  Array(601., dtype=float32),
#  Array(602., dtype=float32),
#  Array(603., dtype=float32),
#  Array(604., dtype=float32),
#  Array(605., dtype=float32),
#  Array(606., dtype=float32),
#  Array(607., dtype=float32),
#  Array(608., dtype=float32),
#  Array(609., dtype=float32),
#  Array(610., dtype=float32),
#  Array(611., dtype=float32),
#  Array(612., dtype=float32),
#  Array(613., dtype=float32),
#  Array(614., dtype=float32),
#  Array(615., dtype=float32),
#  Array(616., dtype=float32),
#  Array(617., dtype=float32),
#  Array(618., dtype=float32),
#  Array(619., dtype=float32),
#  Array(620., dtype=float32),
#  Array(621., dtype=float32),
#  Array(622., dtype=float32),
#  Array(623., dtype=float32),
#  Array(624., dtype=float32),
#  Array(625., dtype=float32),
#  Array(626., dtype=float32),
#  Array(627., dtype=float32),
#  Array(628., dtype=float32),
#  Array(629., dtype=float32),
#  Array(630., dtype=float32),
#  Array(631., dtype=float32),
#  Array(632., dtype=float32),
#  Array(633., dtype=float32),
#  Array(634., dtype=float32),
#  Array(635., dtype=float32),
#  Array(636., dtype=float32),
#  Array(637., dtype=float32),
#  Array(638., dtype=float32),
#  Array(639., dtype=float32),
#  Array(640., dtype=float32),
#  Array(641., dtype=float32),
#  Array(642., dtype=float32),
#  Array(643., dtype=float32),
#  Array(644., dtype=float32),
#  Array(645., dtype=float32),
#  Array(646., dtype=float32),
#  Array(647., dtype=float32),
#  Array(648., dtype=float32),
#  Array(649., dtype=float32),
#  Array(650., dtype=float32),
#  Array(651., dtype=float32),
#  Array(652., dtype=float32),
#  Array(653., dtype=float32),
#  Array(654., dtype=float32),
#  Array(655., dtype=float32),
#  Array(656., dtype=float32),
#  Array(657., dtype=float32),
#  Array(658., dtype=float32),
#  Array(659., dtype=float32),
#  Array(660., dtype=float32),
#  Array(661., dtype=float32),
#  Array(662., dtype=float32),
#  Array(663., dtype=float32),
#  Array(664., dtype=float32),
#  Array(665., dtype=float32),
#  Array(666., dtype=float32),
#  Array(667., dtype=float32),
#  Array(668., dtype=float32),
#  Array(669., dtype=float32),
#  Array(670., dtype=float32),
#  Array(671., dtype=float32),
#  Array(672., dtype=float32),
#  Array(673., dtype=float32),
#  Array(674., dtype=float32),
#  Array(675., dtype=float32),
#  Array(676., dtype=float32),
#  Array(677., dtype=float32),
#  Array(678., dtype=float32),
#  Array(679., dtype=float32),
#  Array(680., dtype=float32),
#  Array(681., dtype=float32),
#  Array(682., dtype=float32),
#  Array(683., dtype=float32),
#  Array(684., dtype=float32),
#  Array(685., dtype=float32),
#  Array(686., dtype=float32),
#  Array(687., dtype=float32),
#  Array(688., dtype=float32),
#  Array(689., dtype=float32),
#  Array(690., dtype=float32),
#  Array(691., dtype=float32),
#  Array(692., dtype=float32),
#  Array(693., dtype=float32),
#  Array(694., dtype=float32),
#  Array(695., dtype=float32),
#  Array(696., dtype=float32),
#  Array(697., dtype=float32),
#  Array(698., dtype=float32),
#  Array(699., dtype=float32),
#  Array(700., dtype=float32),
#  Array(701., dtype=float32),
#  Array(702., dtype=float32),
#  Array(703., dtype=float32),
#  Array(704., dtype=float32),
#  Array(705., dtype=float32),
#  Array(706., dtype=float32),
#  Array(707., dtype=float32),
#  Array(708., dtype=float32),
#  Array(709., dtype=float32),
#  Array(710., dtype=float32),
#  Array(711., dtype=float32),
#  Array(712., dtype=float32),
#  Array(713., dtype=float32),
#  Array(714., dtype=float32),
#  Array(715., dtype=float32),
#  Array(716., dtype=float32),
#  Array(717., dtype=float32),
#  Array(718., dtype=float32),
#  Array(719., dtype=float32),
#  Array(720., dtype=float32),
#  Array(721., dtype=float32),
#  Array(722., dtype=float32),
#  Array(723., dtype=float32),
#  Array(724., dtype=float32),
#  Array(725., dtype=float32),
#  Array(726., dtype=float32),
#  Array(727., dtype=float32),
#  Array(728., dtype=float32),
#  Array(729., dtype=float32),
#  Array(730., dtype=float32),
#  Array(731., dtype=float32),
#  Array(732., dtype=float32),
#  Array(733., dtype=float32),
#  Array(734., dtype=float32),
#  Array(735., dtype=float32),
#  Array(736., dtype=float32),
#  Array(737., dtype=float32),
#  Array(738., dtype=float32),
#  Array(739., dtype=float32),
#  Array(740., dtype=float32),
#  Array(741., dtype=float32),
#  Array(742., dtype=float32),
#  Array(743., dtype=float32),
#  Array(744., dtype=float32),
#  Array(745., dtype=float32),
#  Array(746., dtype=float32),
#  Array(747., dtype=float32),
#  Array(748., dtype=float32),
#  Array(749., dtype=float32),
#  Array(750., dtype=float32),
#  Array(751., dtype=float32),
#  Array(752., dtype=float32),
#  Array(753., dtype=float32),
#  Array(754., dtype=float32),
#  Array(755., dtype=float32),
#  Array(756., dtype=float32),
#  Array(757., dtype=float32),
#  Array(758., dtype=float32),
#  Array(759., dtype=float32),
#  Array(760., dtype=float32),
#  Array(761., dtype=float32),
#  Array(762., dtype=float32),
#  Array(763., dtype=float32),
#  Array(764., dtype=float32),
#  Array(765., dtype=float32),
#  Array(766., dtype=float32),
#  Array(767., dtype=float32),
#  Array(768., dtype=float32),
#  Array(769., dtype=float32),
#  Array(770., dtype=float32),
#  Array(771., dtype=float32),
#  Array(772., dtype=float32),
#  Array(773., dtype=float32),
#  Array(774., dtype=float32),
#  Array(775., dtype=float32),
#  Array(776., dtype=float32),
#  Array(777., dtype=float32),
#  Array(778., dtype=float32),
#  Array(779., dtype=float32),
#  Array(780., dtype=float32),
#  Array(781., dtype=float32),
#  Array(782., dtype=float32),
#  Array(783., dtype=float32),
#  Array(784., dtype=float32),
#  Array(785., dtype=float32),
#  Array(786., dtype=float32),
#  Array(787., dtype=float32),
#  Array(788., dtype=float32),
#  Array(789., dtype=float32),
#  Array(790., dtype=float32),
#  Array(791., dtype=float32),
#  Array(792., dtype=float32),
#  Array(793., dtype=float32),
#  Array(794., dtype=float32),
#  Array(795., dtype=float32),
#  Array(796., dtype=float32),
#  Array(797., dtype=float32),
#  Array(798., dtype=float32),
#  Array(799., dtype=float32),
#  Array(800., dtype=float32),
#  Array(801., dtype=float32),
#  Array(802., dtype=float32),
#  Array(803., dtype=float32),
#  Array(804., dtype=float32),
#  Array(805., dtype=float32),
#  Array(806., dtype=float32),
#  Array(807., dtype=float32),
#  Array(808., dtype=float32),
#  Array(809., dtype=float32),
#  Array(810., dtype=float32),
#  Array(811., dtype=float32),
#  Array(812., dtype=float32),
#  Array(813., dtype=float32),
#  Array(814., dtype=float32),
#  Array(815., dtype=float32),
#  Array(816., dtype=float32),
#  Array(817., dtype=float32),
#  Array(818., dtype=float32),
#  Array(819., dtype=float32),
#  Array(820., dtype=float32),
#  Array(821., dtype=float32),
#  Array(822., dtype=float32),
#  Array(823., dtype=float32),
#  Array(824., dtype=float32),
#  Array(825., dtype=float32),
#  Array(826., dtype=float32),
#  Array(827., dtype=float32),
#  Array(828., dtype=float32),
#  Array(829., dtype=float32),
#  Array(830., dtype=float32),
#  Array(831., dtype=float32),
#  Array(832., dtype=float32),
#  Array(833., dtype=float32),
#  Array(834., dtype=float32),
#  Array(835., dtype=float32),
#  Array(836., dtype=float32),
#  Array(837., dtype=float32),
#  Array(838., dtype=float32),
#  Array(839., dtype=float32),
#  Array(840., dtype=float32),
#  Array(841., dtype=float32),
#  Array(842., dtype=float32),
#  Array(843., dtype=float32),
#  Array(844., dtype=float32),
#  Array(845., dtype=float32),
#  Array(846., dtype=float32),
#  Array(847., dtype=float32),
#  Array(848., dtype=float32),
#  Array(849., dtype=float32),
#  Array(850., dtype=float32),
#  Array(851., dtype=float32),
#  Array(852., dtype=float32),
#  Array(853., dtype=float32),
#  Array(854., dtype=float32),
#  Array(855., dtype=float32),
#  Array(856., dtype=float32),
#  Array(857., dtype=float32),
#  Array(858., dtype=float32),
#  Array(859., dtype=float32),
#  Array(860., dtype=float32),
#  Array(861., dtype=float32),
#  Array(862., dtype=float32),
#  Array(863., dtype=float32),
#  Array(864., dtype=float32),
#  Array(865., dtype=float32),
#  Array(866., dtype=float32),
#  Array(867., dtype=float32),
#  Array(868., dtype=float32),
#  Array(869., dtype=float32),
#  Array(870., dtype=float32),
#  Array(871., dtype=float32),
#  Array(872., dtype=float32),
#  Array(873., dtype=float32),
#  Array(874., dtype=float32),
#  Array(875., dtype=float32),
#  Array(876., dtype=float32),
#  Array(877., dtype=float32),
#  Array(878., dtype=float32),
#  Array(879., dtype=float32),
#  Array(880., dtype=float32),
#  Array(881., dtype=float32),
#  Array(882., dtype=float32),
#  Array(883., dtype=float32),
#  Array(884., dtype=float32),
#  Array(885., dtype=float32),
#  Array(886., dtype=float32),
#  Array(887., dtype=float32),
#  Array(888., dtype=float32),
#  Array(889., dtype=float32),
#  Array(890., dtype=float32),
#  Array(891., dtype=float32),
#  Array(892., dtype=float32),
#  Array(893., dtype=float32),
#  Array(894., dtype=float32),
#  Array(895., dtype=float32),
#  Array(896., dtype=float32),
#  Array(897., dtype=float32),
#  Array(898., dtype=float32),
#  Array(899., dtype=float32),
#  Array(900., dtype=float32),
#  Array(901., dtype=float32),
#  Array(902., dtype=float32),
#  Array(903., dtype=float32),
#  Array(904., dtype=float32),
#  Array(905., dtype=float32),
#  Array(906., dtype=float32),
#  Array(907., dtype=float32),
#  Array(908., dtype=float32),
#  Array(909., dtype=float32),
#  Array(910., dtype=float32),
#  Array(911., dtype=float32),
#  Array(912., dtype=float32),
#  Array(913., dtype=float32),
#  Array(914., dtype=float32),
#  Array(915., dtype=float32),
#  Array(916., dtype=float32),
#  Array(917., dtype=float32),
#  Array(918., dtype=float32),
#  Array(919., dtype=float32),
#  Array(920., dtype=float32),
#  Array(921., dtype=float32),
#  Array(922., dtype=float32),
#  Array(923., dtype=float32),
#  Array(924., dtype=float32),
#  Array(925., dtype=float32),
#  Array(926., dtype=float32),
#  Array(927., dtype=float32),
#  Array(928., dtype=float32),
#  Array(929., dtype=float32),
#  Array(930., dtype=float32),
#  Array(931., dtype=float32),
#  Array(932., dtype=float32),
#  Array(933., dtype=float32),
#  Array(934., dtype=float32),
#  Array(935., dtype=float32),
#  Array(936., dtype=float32),
#  Array(937., dtype=float32),
#  Array(938., dtype=float32),
#  Array(939., dtype=float32),
#  Array(940., dtype=float32),
#  Array(941., dtype=float32),
#  Array(942., dtype=float32),
#  Array(943., dtype=float32),
#  Array(944., dtype=float32),
#  Array(945., dtype=float32),
#  Array(946., dtype=float32),
#  Array(947., dtype=float32),
#  Array(948., dtype=float32),
#  Array(949., dtype=float32),
#  Array(950., dtype=float32),
#  Array(951., dtype=float32),
#  Array(952., dtype=float32),
#  Array(953., dtype=float32),
#  Array(954., dtype=float32),
#  Array(955., dtype=float32),
#  Array(956., dtype=float32),
#  Array(957., dtype=float32),
#  Array(958., dtype=float32),
#  Array(959., dtype=float32),
#  Array(960., dtype=float32),
#  Array(961., dtype=float32),
#  Array(962., dtype=float32),
#  Array(963., dtype=float32),
#  Array(964., dtype=float32),
#  Array(965., dtype=float32),
#  Array(966., dtype=float32),
#  Array(967., dtype=float32),
#  Array(968., dtype=float32),
#  Array(969., dtype=float32),
#  Array(970., dtype=float32),
#  Array(971., dtype=float32),
#  Array(972., dtype=float32),
#  Array(973., dtype=float32),
#  Array(974., dtype=float32),
#  Array(975., dtype=float32),
#  Array(976., dtype=float32),
#  Array(977., dtype=float32),
#  Array(978., dtype=float32),
#  Array(979., dtype=float32),
#  Array(980., dtype=float32),
#  Array(981., dtype=float32),
#  Array(982., dtype=float32),
#  Array(983., dtype=float32),
#  Array(984., dtype=float32),
#  Array(985., dtype=float32),
#  Array(986., dtype=float32),
#  Array(987., dtype=float32),
#  Array(988., dtype=float32),
#  Array(989., dtype=float32),
#  Array(990., dtype=float32),
#  Array(991., dtype=float32),
#  Array(992., dtype=float32),
#  Array(993., dtype=float32),
#  Array(994., dtype=float32),
#  Array(995., dtype=float32),
#  Array(996., dtype=float32),
#  Array(997., dtype=float32),
#  Array(998., dtype=float32),
#  Array(999., dtype=float32),
#  Array(1000., dtype=float32),
#  ...]

# %%
#jax.lax.scan() primitive goes (scans) along the array and calculates a given function for each element and an accumulated state (called carry)
def cumulative_sum_fast(x):
  result, array = jax.lax.scan(lambda carry, elem:(carry + elem, carry + elem), 1.0, x)
  return array

# %%
j = jax.make_jaxpr(cumulative_sum_fast)(jnp.ones(10000))

# %%
len(j.jaxpr.eqns)
# Out:
# 1

# %%
# %time cs = jax.jit(cumulative_sum_fast)(jnp.ones(10000))
# Out:
# CPU times: user 638 ms, sys: 2.12 ms, total: 641 ms
# Wall time: 618 ms

# %% [markdown]
# ##Annotating classes with JIT

# %%
class ScaleClass:
  def __init__(self, scale: jnp.array):
    self.scale = scale

  @jax.jit
  def apply(self, x: jnp.array):
    return self.scale * x

# %%
scale_double = ScaleClass(2)

# %%
scale_double.apply(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-810086245.py in <cell line: 0>()
# ----> 1 scale_double.apply(10)
#
#     [... skipping hidden 5 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/pjit.py in _infer_input_type(fun, dbg, explicit_args)
#     678   except TypeError:
#     679     arg_description = f"path {dbg.arg_names[i] if dbg.arg_names is not None else 'unknown'}"  # pytype: disable=name-error
# --> 680     raise TypeError(
#     681       f"Error interpreting argument to {fun} as an abstract array."
#     682       f" The problematic value is of type {type(x)} and was passed to"  # pytype: disable=name-error
#
# TypeError: Error interpreting argument to <function ScaleClass.apply at 0x7af486c668e0> as an abstract array. The problematic value is of type <class '__main__.ScaleClass'> and was passed to the function at path self.
# This typically means that a jit-wrapped function was called with a non-array argument, and this argument was not marked as static using the static_argnums or static_argnames parameters of jax.jit.

# %%
from functools import partial
class ScaleClass:
  def __init__(self, scale: jnp.array):
    self.scale = scale

  def apply(self, x: jnp.array):
    return _apply_helper(self.scale, x)

# %%
@partial(jax.jit, static_argnums = 0) #Uses JIT annotation with the scale parameter being static
def _apply_helper(scale, x):
  return scale * x

# %%
scale_double = ScaleClass(2)

# %%
scale_double.apply(10)
# Out:
# Array(20, dtype=int32, weak_type=True)
